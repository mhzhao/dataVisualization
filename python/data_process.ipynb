# %%
import pandas as pd

# %%
code_data = pd.read_csv("../data/GDP/country_code.csv")
gdp_data = pd.read_csv("../data/GDP/API_NY.GDP.MKTP.KD.ZG_DS2_en_csv_v2_713083.csv", skiprows=[0,1,2,3])

# %%
# gdp_data.fillna(0)
code_data
# Out:
#                COUNTRY COUNTRY CODE ISO CODES  POPULATION   AREA KM2  \
# 0          Afghanistan           93  AF / AFG  29,121,286    647,500
# 1              Albania          355  AL / ALB   2,986,952     28,748
# 2              Algeria          213  DZ / DZA  34,586,184  2,381,740
# 3       American Samoa        1-684  AS / ASM      57,881        199
# 4              Andorra          376  AD / AND      84,000        468
# ..                 ...          ...       ...         ...        ...
# 235  Wallis and Futuna          681  WF / WLF      16,025        274
# 236     Western Sahara          212  EH / ESH     273,008    266,000
# 237              Yemen          967  YE / YEM  23,495,361    527,970
# 238             Zambia          260  ZM / ZMB  13,460,305    752,614
# 239           Zimbabwe          263  ZW / ZWE  11,651,858    390,580
#
#           GDP $USD
# 0    20.65 Billion
# 1     12.8 Billion
# 2    215.7 Billion
# 3    462.2 Million
# 4      4.8 Billion
# ...

# %%
two_list = []
three_list = []
for d in code_data["ISO CODES"].str.split("/"):
    two_list.append(d[0].strip(" "))
    three_list.append(d[1].strip(" "))

three_dict = {}
for index, name in enumerate(code_data["COUNTRY"]):
    three_dict[three_list[index]] = name
    
# three_dict

# %%
gdp_data["Country/Other"] =  [d in three_dict for d in gdp_data["Country Code"]]

# %%
country_gdp = gdp_data[gdp_data["Country/Other"]].fillna(0)

# %%
country_gdp.to_csv("../data/GDP/country_GDP.csv", index=False)

# %%
country_gdp
# Out:
#      Country Name Country Code         Indicator Name     Indicator Code  \
# 0           Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 1     Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 2          Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 3         Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 4         Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# ..            ...          ...                    ...                ...
# 259        Kosovo          XKX  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 260   Yemen, Rep.          YEM  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 261  South Africa          ZAF  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 262        Zambia          ZMB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 263      Zimbabwe          ZWE  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
#
#      1960      1961      1962      1963       1964       1965  ...       2012  \
# ...
